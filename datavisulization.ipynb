# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:\\Users\\dell\\Downloads\\Vehicles_2018.csv')
# Out:
# C:\Users\dell\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Accident_Index  Vehicle_Reference  Vehicle_Type  Towing_and_Articulation  \
# 0  2018010080971                  1             9                        0
# 1  2018010080971                  2             8                        0
# 2  2018010080973                  1             9                        0
# 3  2018010080974                  1             8                        0
# 4  2018010080974                  2             9                        0
#
#    Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  Junction_Location  \
# 0                 18                                 0                  0
# 1                 18                                 0                  0
# 2                 18                                 0                  2
# 3                  7                                 0                  8
# 4                 18                                 0                  1
#
#    Skidding_and_Overturning  Hit_Object_in_Carriageway  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Accident_Index  Vehicle_Reference  Vehicle_Type  \
# 0       2018010080971                  1             9
# 1       2018010080971                  2             8
# 2       2018010080973                  1             9
# 3       2018010080974                  1             8
# 4       2018010080974                  2             9
# ...               ...                ...           ...
# 226404  2018984116018                  1             9
# 226405  2018984116018                  2             9
# 226406  2018984116018                  3             9
# 226407  2018984116318                  1             2
# 226408  2018984116418                  1             9
#
#         Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                             0                 18
# 1                             0                 18
# 2                             0                 18
# 3                             0                  7
# ...

# %%
data.isnull().sum()
# Out:
# Accident_Index                      0
# Vehicle_Reference                   0
# Vehicle_Type                        0
# Towing_and_Articulation             0
# Vehicle_Manoeuvre                   0
# Vehicle_Location-Restricted_Lane    0
# Junction_Location                   0
# Skidding_and_Overturning            0
# Hit_Object_in_Carriageway           0
# Vehicle_Leaving_Carriageway         0
# Hit_Object_off_Carriageway          0
# 1st_Point_of_Impact                 0
# Was_Vehicle_Left_Hand_Drive?        0
# Journey_Purpose_of_Driver           0
# Sex_of_Driver                       0
# Age_of_Driver                       0
# Age_Band_of_Driver                  0
# Engine_Capacity_(CC)                0
# Propulsion_Code                     0
# Age_of_Vehicle                      0
# Driver_IMD_Decile                   0
# Driver_Home_Area_Type               0
# Vehicle_IMD_Decile                  0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random

# %%
plt.scatter(data["Junction_Location"],data["Skidding_and_Overturning"],color="red")
plt.title("Scater plot for bivariate analysis")
plt.xlabel("Location")
plt.ylabel("Skidding")
plt.show()

# %%
plt.hist(data["Age_of_Driver"],bins=20)
plt.title("histogram for age")
plt.xlabel("age")
plt.ylabel("frequency")
plt.show()

# %%
import seaborn as sns
sns.barplot(data['Sex_of_Driver'],data['Journey_Purpose_of_Driver'])
plt.title("barlot")
# Out:
# Text(0.5, 1.0, 'barlot')

# %%
sns.jointplot(x='Sex_of_Driver',y='Age_of_Driver',data=data,kind='scatter')

# %%
sns.distplot(data["Vehicle_Manoeuvre"],bins=25,kde=True)

# %%
data.corr()
# Out:
#                                   Vehicle_Reference  Vehicle_Type  \
# Vehicle_Reference                          1.000000     -0.001426
# Vehicle_Type                              -0.001426      1.000000
# Towing_and_Articulation                    0.006582      0.116035
# Vehicle_Manoeuvre                         -0.026694     -0.036171
# Vehicle_Location-Restricted_Lane          -0.000285     -0.000675
# Junction_Location                         -0.017704     -0.046745
# Skidding_and_Overturning                  -0.019740     -0.025246
# Hit_Object_in_Carriageway                 -0.018182     -0.009126
# Vehicle_Leaving_Carriageway               -0.028384     -0.000611
# Hit_Object_off_Carriageway                -0.028769     -0.002812
# 1st_Point_of_Impact                        0.010130     -0.002280
# Was_Vehicle_Left_Hand_Drive?               0.000864     -0.033702
# Journey_Purpose_of_Driver                  0.009453     -0.104227
# ...

# %%
sns.heatmap(data.corr(),cmap="coolwarm",annot=True)

# %%
sns.boxplot(x='Sex_of_Driver',y='Age_of_Driver',data=data)

# %%
sns.countplot(x='Age_of_Driver',data=data)

# %%
data=pd.read_csv('C:\\Users\\dell\\Downloads\\Casualties_2018.csv')

# %%
data.head()
# Out:
#   Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  2018010080971                  1                   1               2
# 1  2018010080971                  2                   2               1
# 2  2018010080973                  1                   1               3
# 3  2018010080974                  1                   1               1
# 4  2018010080981                  1                   1               1
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                2               50                     8                  3
# 1                1               48                     8                  3
# 2                1               29                     6                  3
# 3                1               40                     7                  3
# 4                1               27                     6                  2
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0       2018010080971                  1                   1               2
# 1       2018010080971                  2                   2               1
# 2       2018010080973                  1                   1               3
# 3       2018010080974                  1                   1               1
# 4       2018010080981                  1                   1               1
# ...               ...                ...                 ...             ...
# 160592  2018984115718                  2                   1               2
# 160593  2018984115918                  1                   1               3
# 160594  2018984116018                  2                   1               2
# 160595  2018984116318                  1                   1               1
# 160596  2018984116418                  1                   1               1
#
# ...

# %%
data.isnull().sum()
# Out:
# Accident_Index                        0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# Casualty_IMD_Decile                   0
# dtype: int64

# %%
plt.scatter(data["Bus_or_Coach_Passenger"],data["Car_Passenger"],color="red")
plt.title("Scater plot for bivariate analysis")
plt.xlabel("bus")
plt.ylabel("car")
plt.show()

# %%
plt.hist(data["Age_of_Casualty"],bins=20)
plt.title("histogram for age")
plt.xlabel("age")
plt.ylabel("frequency")
plt.show()

# %%
import seaborn as sns
sns.barplot(data['Age_Band_of_Casualty'],data['Age_of_Casualty'])
plt.title("barlot")
# Out:
# Text(0.5, 1.0, 'barlot')

# %%
sns.jointplot(x='Sex_of_Casualty',y='Age_of_Casualty',data=data,kind='scatter')

# %%
sns.distplot(data["Age_Band_of_Casualty"],bins=25,kde=True)

# %%
data.corr()
# Out:
#                                     Vehicle_Reference  Casualty_Reference  \
# Vehicle_Reference                            1.000000            0.018683
# Casualty_Reference                           0.018683            1.000000
# Casualty_Class                              -0.057606            0.046151
# Sex_of_Casualty                             -0.000106            0.024792
# Age_of_Casualty                              0.005259           -0.032982
# Age_Band_of_Casualty                         0.007384           -0.039947
# Casualty_Severity                            0.014475            0.018211
# Pedestrian_Location                         -0.053994           -0.041493
# Pedestrian_Movement                         -0.053514           -0.034262
# Car_Passenger                                0.011156            0.142952
# Bus_or_Coach_Passenger                      -0.007709            0.074161
# Pedestrian_Road_Maintenance_Worker          -0.038152           -0.024368
# ...

# %%
sns.heatmap(data.corr(),cmap="coolwarm",annot=True)

# %%
sns.boxplot(x='Age_of_Casualty',data=data)

# %%
sns.countplot(x='Age_of_Casualty',data=data)
